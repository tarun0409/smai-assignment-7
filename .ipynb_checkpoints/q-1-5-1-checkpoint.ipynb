# %%
import pandas as pd
import numpy as np
import operator
import json

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

# %%
class LinearRegression:
    theta = None
    
    def predict(self, X):
        Y_pred = np.dot(X,self.theta.T)
        return Y_pred
    
    def compute_error(self, y_pred, y_actual, regularization_method, l):
        m = len(y_actual)
        error = (1.0/float(m))*np.sum((y_pred-y_actual)*(y_pred-y_actual))
        reg_term = 0
        if regularization_method == 'lasso':
            reg_term = np.sum(np.abs(self.theta))
        if regularization_method == 'ridge':
            reg_term = np.sum(np.square(self.theta))
            
        error = error + (l*reg_term)
        return error
    
    def compute_gradient(self, X, h, Y,regularization_method,l):
        m = len(Y)
        grad = (2.0/float(m))*np.sum(X*(h-Y), axis=0)
        reg_term = 0
        if regularization_method == 'lasso':
            reg_term = np.sum(np.divide(self.theta,np.abs(self.theta)))
        if regularization_method == 'ridge':
            reg_term = 2*np.sum(self.theta)
            
        grad = grad + (l*reg_term)
        return grad
    
    def train(self, X, y, alpha, max_epochs, regularization_method,l):
        self.theta = None
        self.theta = np.random.rand(1,X_train.shape[1])
        m = len(X_train)
        its = list()
        errs = list()
        for i in range(0,max_epochs):
#             X = X_train.values
            h = np.dot(X,self.theta.T)
#             Y = y_train.values
            self.theta = self.theta - alpha*self.compute_gradient(X,h,y,regularization_method,l)
            
            y_pred = np.dot(X,self.theta.T)
            err = self.compute_error(y_pred,y, regularization_method,l)
            its.append((i+1))
            errs.append(err)
        return (its,errs)

# %%
def train_data(X_train, y_train, X_test, y_test):
    ln_mse = LinearRegression()
    its_mse,errs_mse = ln_mse.train(X_train,y_train,0.1, 100,'ridge',0.01)
    y_train_pred_mse = ln_mse.predict(X_train)
    y_test_pred_mse = ln_mse.predict(X_test)
    train_mse = ln_mse.compute_error(y_train_pred_mse, y_train,'ridge',0.01)
    test_mse = ln_mse.compute_error(y_test_pred_mse, y_test,'ridge',0.01)
    return train_mse,test_mse

# %%
data = pd.read_csv("admission_data.csv")
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0         242        317          103                  2  2.5  2.0  8.15
# 1         334        319          108                  3  3.0  3.5  8.54
# 2           4        322          110                  3  3.5  2.5  8.67
# 3          45        326          113                  5  4.5  4.0  9.40
# 4         232        319          106                  3  3.5  2.5  8.33
#
#    Research  Chance of Admit
# 0         0             0.65
# 1         1             0.71
# 2         1             0.80
# 3         1             0.91
# 4         1             0.74

# %%
X_pd = data[['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA', 'Research']]
y_pd = data[['Chance of Admit']]
for col in X_pd:
    mean = X_pd[col].mean()
    std = X_pd[col].std()
    X_pd[col] = (X_pd[col] - mean)/std
X_pd['Ones'] = [1]*len(X_pd)
X = X_pd.values
y = y_pd.values
for k in range(2,201):
    kf = KFold(n_splits=k)
    total_train_error = 0.0
    total_test_error = 0.0
    for train_index,test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        train_mse,test_mse = train_data(X_train,y_train,X_test,y_test)
        total_train_error += train_mse
        total_test_error += test_mse
    print 'K = '+str(k)
    print 'Average train error : '+str(total_train_error/k)
    print 'Average test error : '+str(total_test_error/k)
# Out:
# /home/tarunm/.local/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/tarunm/.local/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# K = 2
# Average train error : 0.008990635111588763
# Average test error : 0.009334076624409705
# K = 3
# Average train error : 0.008966828146078945
# Average test error : 0.009172569439518299
# K = 4
# Average train error : 0.008984388967494579
# Average test error : 0.00914985739139307
# K = 5
# Average train error : 0.008994436797865721
# Average test error : 0.009163256034112407
# K = 6
# Average train error : 0.009002565279656002
# Average test error : 0.009096459233298127
# K = 7
# Average train error : 0.008974408691578001
# Average test error : 0.00910644675489233
# K = 8
# Average train error : 0.008997567117691329
# Average test error : 0.009117322589135137
# K = 9
# Average train error : 0.009005800093437941
# Average test error : 0.009174649445786224
# K = 10
# Average train error : 0.009011243750379915
# Average test error : 0.009141487965405915
# K = 11
# Average train error : 0.008994251631654557
# Average test error : 0.00914857977656462
# K = 12
# Average train error : 0.008989146540960209
# Average test error : 0.009093284617057768
# K = 13
# Average train error : 0.009000478588886977
# Average test error : 0.009056811987881662
# K = 14
# Average train error : 0.009003032554567242
# Average test error : 0.0091207127655159
# K = 15
# Average train error : 0.008986517485035957
# Average test error : 0.009138681909801997
# K = 16
# Average train error : 0.009002928882356272
# Average test error : 0.009159174684038287
# K = 17
# Average train error : 0.008985285115667284
# Average test error : 0.009119194907244053
# K = 18
# Average train error : 0.009016423565838634
# Average test error : 0.009081591809349102
# K = 19
# Average train error : 0.008997871452056072
# Average test error : 0.009108977895452697
# K = 20
# Average train error : 0.008997757200702856
# Average test error : 0.009136502893856301
# K = 21
# Average train error : 0.009006142909720528
# Average test error : 0.009134861368966638
# K = 22
# Average train error : 0.008999726744934163
# Average test error : 0.009108787747380163
# K = 23
# Average train error : 0.009002737180383571
# Average test error : 0.009132232700502514
# K = 24
# Average train error : 0.00899868583652739
# Average test error : 0.009083665133226549
# K = 25
# Average train error : 0.009002127750560534
# Average test error : 0.009170197302503215
# K = 26
# Average train error : 0.00900262901355704
# Average test error : 0.009149348477669142
# K = 27
# Average train error : 0.009002954684581309
# Average test error : 0.009107610886648906
# K = 28
# Average train error : 0.009004127237364106
# Average test error : 0.009128575152883076
# K = 29
# Average train error : 0.008993914638489054
# Average test error : 0.009064161402914842
# K = 30
# Average train error : 0.00900520531361922
# Average test error : 0.00911962704324873
# K = 31
# Average train error : 0.009000390215627086
# Average test error : 0.009124424085482735
# K = 32
# Average train error : 0.008997632614243242
# Average test error : 0.009151949892715441
# K = 33
# Average train error : 0.009004610071465607
# Average test error : 0.009145410361483397
# K = 34
# Average train error : 0.008997015856712124
# Average test error : 0.009077294201716888
# K = 35
# Average train error : 0.009000086159285357
# Average test error : 0.009140728952722705
# K = 36
# Average train error : 0.00900231432836606
# Average test error : 0.009087894521394727
# K = 37
# Average train error : 0.009007781739484489
# Average test error : 0.009166830985958812
# K = 38
# Average train error : 0.009005448387786465
# Average test error : 0.009161901758528893
# K = 39
# Average train error : 0.008999336603651252
# Average test error : 0.009131602724252471
# K = 40
# Average train error : 0.009000139751392463
# Average test error : 0.009074518943505454
# K = 41
# Average train error : 0.009003519802328922
# Average test error : 0.009100299464488811
# K = 42
# Average train error : 0.00899970451872352
# Average test error : 0.009156779709837148
# K = 43
# Average train error : 0.008998542693168117
# Average test error : 0.009163741100337242
# K = 44
# Average train error : 0.009002235542485073
# Average test error : 0.009130466172060363
# K = 45
# Average train error : 0.0090032453834532
# Average test error : 0.00906923435557601
# K = 46
# Average train error : 0.00900304618304071
# Average test error : 0.009096710359535902
# K = 47
# Average train error : 0.009001306726774959
# Average test error : 0.009157692124152515
# K = 48
# Average train error : 0.008999102370218016
# Average test error : 0.009170385391939623
# K = 49
# Average train error : 0.008999056343257766
# Average test error : 0.009102915186086274
# K = 50
# Average train error : 0.009007334483152572
# Average test error : 0.009219826752864115
# K = 51
# Average train error : 0.008992156869949686
# Average test error : 0.00918322861521988
# K = 52
# Average train error : 0.009008171489024015
# Average test error : 0.009202517707557504
# K = 53
# Average train error : 0.009000868697405792
# Average test error : 0.009162211868577533
# K = 54
# Average train error : 0.009001491678438181
# Average test error : 0.009138867492691063
# K = 55
# Average train error : 0.009005712449518238
# Average test error : 0.009117851957036899
# K = 56
# Average train error : 0.008995821572799951
# Average test error : 0.009106273792606825
# K = 57
# Average train error : 0.009005333655369633
# Average test error : 0.00916874899172769
# K = 58
# Average train error : 0.009006481707877429
# Average test error : 0.009156280532452744
# K = 59
# Average train error : 0.008990287376053745
# Average test error : 0.009180615287226683
# K = 60
# Average train error : 0.0089960852320822
# Average test error : 0.009126260916623786
# K = 61
# Average train error : 0.00900153530854545
# Average test error : 0.009131566747694143
# K = 62
# Average train error : 0.009006057728402298
# Average test error : 0.009095539392538883
# K = 63
# Average train error : 0.008999896171578746
# Average test error : 0.009085776246056769
# K = 64
# Average train error : 0.009007630711212312
# Average test error : 0.00917525739020624
# K = 65
# Average train error : 0.008999602748940917
# Average test error : 0.009133602504172007
# K = 66
# Average train error : 0.009003123683671779
# Average test error : 0.009154165122423613
# K = 67
# Average train error : 0.008995429608145053
# Average test error : 0.009129188276814245
# K = 68
# Average train error : 0.009003856825083627
# Average test error : 0.009168091445486422
# K = 69
# Average train error : 0.008999431798019507
# Average test error : 0.009156497891212364
# K = 70
# Average train error : 0.008996148032912259
# Average test error : 0.009108642587197045
# K = 71
# Average train error : 0.009010667950986158
# Average test error : 0.00913688196439021
# K = 72
# Average train error : 0.008997001306829464
# Average test error : 0.0091677422609452
# K = 73
# Average train error : 0.009006410572036166
# Average test error : 0.009127936536376068
# K = 74
# Average train error : 0.009001387660685176
# Average test error : 0.009138672054927457
# K = 75
# Average train error : 0.008998157094537811
# Average test error : 0.009119963101146487
# K = 76
# Average train error : 0.008991972970625933
# Average test error : 0.00914350866907359
# K = 77
# Average train error : 0.008997884986392127
# Average test error : 0.009091454370960579
# K = 78
# Average train error : 0.009003606829356284
# Average test error : 0.00915520433102566
# K = 79
# Average train error : 0.009000410902862474
# Average test error : 0.009128428550411117
# K = 80
# Average train error : 0.008999793723332913
# Average test error : 0.009170036386480644
# K = 81
# Average train error : 0.009002710781311402
# Average test error : 0.00911566220557228
# K = 82
# Average train error : 0.00899936334008378
# Average test error : 0.009126247686314719
# K = 83
# Average train error : 0.009002377339456644
# Average test error : 0.009146181960631014
# K = 84
# Average train error : 0.008997923403026903
# Average test error : 0.009103838577857069
# K = 85
# Average train error : 0.00900215022482228
# Average test error : 0.009118287515231421
# K = 86
# Average train error : 0.009001536301940153
# Average test error : 0.0091497079898514
# K = 87
# Average train error : 0.008999837743501016
# Average test error : 0.009109331894916875
# K = 88
# Average train error : 0.009006388781852441
# Average test error : 0.00908273271471912
# K = 89
# Average train error : 0.009000735862607506
# Average test error : 0.009209544630527165
# K = 90
# Average train error : 0.008998918028206508
# Average test error : 0.009132266135501919
# K = 91
# Average train error : 0.008997566110904692
# Average test error : 0.00907286490142193
# K = 92
# Average train error : 0.009003810671357406
# Average test error : 0.009217543298238963
# K = 93
# Average train error : 0.00900251862395622
# Average test error : 0.009089835009075058
# K = 94
# Average train error : 0.009005631902263339
# Average test error : 0.009165034090732107
# K = 95
# Average train error : 0.009003369106807583
# Average test error : 0.009175064988490916
# K = 96
# Average train error : 0.009008789294260884
# Average test error : 0.009224879577768552
# K = 97
# Average train error : 0.008997377648063258
# Average test error : 0.009160935579055604
# K = 98
# Average train error : 0.008997076770413283
# Average test error : 0.009215532602849458
# K = 99
# Average train error : 0.00901158475836643
# Average test error : 0.009275755814034245
